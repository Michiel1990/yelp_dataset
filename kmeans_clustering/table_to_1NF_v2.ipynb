# %% [markdown]
# #### import packages

# %%
import pandas as pd
import sqlite3
import numpy as np

# %% [markdown]
# #### define variables

# %%
#SQLite3 connection
conn = sqlite3.connect('SQLITE3/yelp_database.sqlite3')
c = conn.cursor()

# %% [markdown]
# ### BUSINESS CATEGORIES
# >as this column contains an array we have to convert the table to first normal form to be able to query/analyse efficiently

# %% [markdown]
# #### DF import & clean

# %%
#import SQLite table into df 
business_categories_df = pd.read_sql_query("select business_id,categories from business_main", conn)

# %%
#convert strings to list in column "categories"
def split_list(input_string):
    if input_string is not None:
        output_list = input_string.split(", ")
    else:
        output_list = []
    return output_list

business_categories_df['categories'] = business_categories_df['categories'].apply(split_list)

# %%
#check contents of column
business_categories_df
# Out:
#                    business_id  \
# 0       6iYb2HFDywm3zjuRg0shjw
# 1       tCbdrRPZA0oiIYSmHG3J0w
# 2       bvN78flM8NLprQ1a1y5dRg
# 3       oaepsyvc0J17qwi8cfrOWg
# 4       PE9uqAjdw0E4-8mjGl3wVA
# ...                        ...
# 160580  D2mHoIDXx9N8mS1pGoKV9Q
# 160581  bQX-kwVTyZgcdZGEPzce6Q
# 160582  wvFZ06nmPmQ2-IVoPqVYLA
# 160583  GB75wPibj3IjNauaoCxyGA
# 160584  ngmLL5Y5OT-bYHKU0kKrYA
#
#                                                categories
# 0       [Gastropubs, Food, Beer Gardens, Restaurants, ...
# 1       [Salad, Soup, Sandwiches, Delis, Restaurants, ...
# 2       [Antiques, Fashion, Used, Vintage & Consignmen...
# 3                            [Beauty & Spas, Hair Salons]
# 4       [Gyms, Active Life, Interval Training Gyms, Fi...
# ...                                                   ...
# 160580  [Real Estate, Real Estate Services, Home Servi...
# 160581    [Health Markets, Food, Specialty Food, Grocery]
# 160582  [Arts & Entertainment, Paint & Sip, Art Classe...
# 160583            [Cuban, Sandwiches, Restaurants, Cafes]
# 160584  [Restaurants, Middle Eastern, Mediterranean, P...
#
# [160585 rows x 2 columns]

# %%
#test if column is correctly converted to dtype list for first 10 rows
for x, y in enumerate(business_categories_df["categories"].head(10)):
    print("index",x,"is",type(y))
# Out:
# index 0 is <class 'list'>
# index 1 is <class 'list'>
# index 2 is <class 'list'>
# index 3 is <class 'list'>
# index 4 is <class 'list'>
# index 5 is <class 'list'>
# index 6 is <class 'list'>
# index 7 is <class 'list'>
# index 8 is <class 'list'>
# index 9 is <class 'list'>

# %% [markdown]
# #### METHOD 2: create boolean table with one row per business_id but every category is unique column

# %%
#create dictionairy of unique items (=key), including number of appearances (=value)
business_categories_dict = {}
for x in business_categories_df['categories']:
    if x is not None:
        for y in x:
            if y not in business_categories_dict:
                business_categories_dict[y] = 1
            else:
                business_categories_dict[y] += 1
    else:
        continue

# %%
print(business_categories_dict)
# Out:
# {'Gastropubs': 502, 'Food': 29469, 'Beer Gardens': 157, 'Restaurants': 50763, 'Bars': 10741, 'American (Traditional)': 6541, 'Beer Bar': 738, 'Nightlife': 11990, 'Breweries': 749, 'Salad': 2649, 'Soup': 986, 'Sandwiches': 7272, 'Delis': 1850, 'Cafes': 2871, 'Vegetarian': 1482, 'Antiques': 603, 'Fashion': 6599, 'Used': 815, 'Vintage & Consignment': 815, 'Shopping': 26205, 'Furniture Stores': 1667, 'Home & Garden': 5499, 'Beauty & Spas': 16574, 'Hair Salons': 5900, 'Gyms': 2052, 'Active Life': 9231, 'Interval Training Gyms': 253, 'Fitness & Instruction': 4741, 'Thai': 1363, 'Dentists': 3139, 'Health & Medical': 15102, 'Orthodontists': 803, '
# %%
#create dataframe with booleans
def boolean_df(item_lists, unique_items):
    # Create empty dict
    bool_dict = {}
    # Loop through all the tags
    for i, item in enumerate(unique_items):
        # Apply boolean mask
        bool_dict[item] = item_lists.apply(lambda x: item in x)
    # Return the results as a dataframe
    return pd.DataFrame(bool_dict)

# %%
business_categories_bool = boolean_df(business_categories_df['categories'], business_categories_dict.keys())

# %%
final_df = business_categories_df.merge(business_categories_bool,left_index=True, right_index=True)
final_df
# Out:
#                    business_id  \
# 0       6iYb2HFDywm3zjuRg0shjw
# 1       tCbdrRPZA0oiIYSmHG3J0w
# 2       bvN78flM8NLprQ1a1y5dRg
# 3       oaepsyvc0J17qwi8cfrOWg
# 4       PE9uqAjdw0E4-8mjGl3wVA
# ...                        ...
# 160580  D2mHoIDXx9N8mS1pGoKV9Q
# 160581  bQX-kwVTyZgcdZGEPzce6Q
# 160582  wvFZ06nmPmQ2-IVoPqVYLA
# 160583  GB75wPibj3IjNauaoCxyGA
# 160584  ngmLL5Y5OT-bYHKU0kKrYA
#
#                                                categories  Gastropubs   Food  \
# 0       [Gastropubs, Food, Beer Gardens, Restaurants, ...        True   True
# 1       [Salad, Soup, Sandwiches, Delis, Restaurants, ...       False  False
# 2       [Antiques, Fashion, Used, Vintage & Consignmen...       False  False
# 3                            [Beauty & Spas, Hair Salons]       False  False
# 4       [Gyms, Active Life, Interval Training Gyms, Fi...       False  False
# ...                                                   ...         ...    ...
# 160580  [Real Estate, Real Estate Services, Home Servi...       False  False
# 160581    [Health Markets, Food, Specialty Food, Grocery]       False   True
# 160582  [Arts & Entertainment, Paint & Sip, Art Classe...       False  False
# 160583            [Cuban, Sandwiches, Restaurants, Cafes]       False  False
# 160584  [Restaurants, Middle Eastern, Mediterranean, P...       False  False
#
#         Beer Gardens  Restaurants   Bars  American (Traditional)  Beer Bar  \
# 0               True         True   True                    True      True
# 1              False         True  False                   False     False
# 2              False        False  False                   False     False
# 3              False        False  False                   False     False
# 4              False        False  False                   False     False
# ...              ...          ...    ...                     ...       ...
# 160580         False        False  False                   False     False
# 160581         False        False  False                   False     False
# 160582         False        False  False                   False     False
# 160583         False         True  False                   False     False
# 160584         False         True  False                   False     False
#
#         Nightlife  ...  Court Reporters  Nephrologists  Mohels  \
# 0            True  ...            False          False   False
# 1           False  ...            False          False   False
# 2           False  ...            False          False   False
# 3           False  ...            False          False   False
# 4           False  ...            False          False   False
# ...           ...  ...              ...            ...     ...
# 160580      False  ...            False          False   False
# 160581      False  ...            False          False   False
# 160582      False  ...            False          False   False
# 160583      False  ...            False          False   False
# 160584      False  ...            False          False   False
#
#         Christmas Markets  Patent Law  Pickleball   Pita  Oriental  \
# 0                   False       False       False  False     False
# 1                   False       False       False  False     False
# 2                   False       False       False  False     False
# 3                   False       False       False  False     False
# 4                   False       False       False  False     False
# ...                   ...         ...         ...    ...       ...
# 160580              False       False       False  False     False
# 160581              False       False       False  False     False
# 160582              False       False       False  False     False
# 160583              False       False       False  False     False
# 160584              False       False       False  False     False
#
#         Free Diving  Fischbroetchen
# 0             False           False
# 1             False           False
# 2             False           False
# 3             False           False
# 4             False           False
# ...             ...             ...
# 160580        False           False
# 160581        False           False
# 160582        False           False
# 160583        False           False
# 160584        False           False
#
# [160585 rows x 1332 columns]
